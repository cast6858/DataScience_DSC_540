# %% [markdown]
# # Felipe Castillo
# # Twitter
# # Data Preparation
# # 2/17/2022

# %%
import sys
import twitter
import tweepy
#!{sys.executable} -m pip install tweepy
#Uploading all twitter packages dependencies
from twitter import *
import os
#storing key privitely in python Twitter cred module-

os.chdir("C:\DataScience_DSC_540\Week9_10")

import TwitterCredentails

# %%
# Getting credentails from Twitter Credentails module
#values save in a private module 

auth = tweepy.OAuthHandler(TwitterCredentails.consumer_key,TwitterCredentails.consumer_secret)
auth.set_access_token(TwitterCredentails.access_token,TwitterCredentails.access_token_secret)

# %%
#setting an instance 
api = tweepy.API(auth)

# %%
#Got this id from twitter by a post on NFTS
#1493751863061196801
#Checking Gary V feed 

id = 1493751863061196801

retweets_list = api.search_tweets(id)


print(retweets_list)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000016D39D2CAC0>, _json={'created_at': 'Thu Feb 17 00:06:45 +0000 2022', 'id': 1494100972511150086, 'id_str': '1494100972511150086', 'text': 'RT @garyvee: 😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'garyvee', 'name': 'Gary Vaynerchuk', 'id': 5768872, 'id_str': '5768872', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1334583272735727619, 'id_str': '1334583272735727619', 'name': 'Andrew Bernard Merritt', 'screen_name': 'AndrewBeMerritt', 'location': 'Hurst, TX', 'description': 'Future content creator/ taken /Gaming account @Fangbound /Don`t use my characters to rol
# ...

# %%
user_name = "GaryVaynerchuk"
user = api.get_user(screen_name=user_name)

status_count = user.statuses_count

print(status_count)
# Out:
# 1
